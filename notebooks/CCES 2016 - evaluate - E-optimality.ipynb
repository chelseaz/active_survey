# %%
library(dplyr)
library(ggplot2)
library(gridExtra)
library(tidyr)
filepath <- '/Users/cyz/survey/active_survey/'
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
cur_rank <- 4
cur_alpha <- 1
cur_completer <- 'bpmf'
cur_vmethod <- 'row-norm'
opt_type <- 'E'

# %%
source('eval_util.R')

# %%
results <- read_results('cces16_eopt') %>% filter(strategy != 'epsilon_greedy')
get_sample_sizes(results)
# Out:
#   eval_method completer strategy   rank v_method optimality alpha n
# 1 sparsify    bpmf      active     2    row-norm E          1     10
# 2 sparsify    bpmf      active     4    row-norm E          1     10
# 3 sparsify    bpmf      random     2    row-norm E          1     10
# 4 sparsify    bpmf      random     4    row-norm E          1     10
# 5 sparsify    bpmf      sequential 2    row-norm E          1     10
# 6 sparsify    bpmf      sequential 4    row-norm E          1     10

# %%
strategy_colors <- c('random'='black', 'active'='red', 'sequential'='blue')

# %%
plot_aggregate_error(optimality_type=opt_type)
plot_aggregate_error(optimality_type=opt_type, metric='mae')
# Out:
# plot without title
# plot without title

# %%
plot_aggregate_error_inverse(optimality_type=opt_type)
plot_aggregate_error_inverse(optimality_type=opt_type, metric='mae')
# Out:
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.014”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.001”Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  4.3438e-16”
# plot without title
# plot without title

# %%
plot_method_comparison(optimality_type=opt_type, base_method='active', compare_method='random')
plot_method_comparison(optimality_type=opt_type, base_method='active', compare_method='random', metric='mae')
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_path).”Warning message:
# “Removed 2 rows containing missing values (geom_path).”Warning message:
# “Removed 2 rows containing missing values (geom_path).”
# plot without title
# plot without title

# %%
# plot_per_question_error(optimality_type=opt_type)

# %%
# plot_per_question_comparison(y_var='mae', sd_var='sdae', y_var_readable='MAE')
# plot_per_question_comparison(y_var='bias', y_var_readable='bias')

# %%
# base_method = 'random'
# compare_method = 'active'
# plot_error_diff(optimality_type=opt_type, base_method=base_method, compare_method=compare_method, y_var='mae', show_max_qnum=20)
# plot_error_diff(optimality_type=opt_type, base_method=base_method, compare_method=compare_method, y_var='mae', show_max_qnum=20, plot_error_diff_fn=plot_error_diff_box)
# plot_effect_size(optimality_type=opt_type, base_method=base_method, compare_method=compare_method, y_var='mae', sd_var='sdae', show_max_qnum=20)
# plot_effect_size(optimality_type=opt_type, base_method=base_method, compare_method=compare_method, y_var='mae', sd_var='sdae', show_max_qnum=20, plot_error_diff_fn=plot_error_diff_box)
