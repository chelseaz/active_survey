# %%
library(dplyr)
library(ggplot2)
library(gridExtra)
library(tidyr)
filepath <- '/Users/cyz/survey/active_survey/'
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
dataset <- 'cces16'
cur_rank <- 4
cur_alpha <- 1
cur_completer <- 'bpmf'
cur_vmethod <- 'row-norm'

# %%
source('eval_util.R')

# %%
results <- read_results(dataset) #%>% filter(strategy %in% c('active', 'epsilon_greedy'))
get_sample_sizes(results)
# Out:
#    eval_method completer strategy       rank v_method optimality alpha n
# 1  lococv      bpmf      active         2    row-norm A          1      1
# 2  lococv      bpmf      active         4    row-norm A          1      1
# 3  lococv      bpmf      epsilon_greedy 2    row-norm A          1      1
# 4  lococv      bpmf      epsilon_greedy 4    row-norm A          1      1
# 5  lococv      bpmf      random         2    row-norm A          1      1
# 6  lococv      bpmf      random         4    row-norm A          1      1
# 7  lococv      bpmf      sequential     2    row-norm A          1      1
# 8  lococv      bpmf      sequential     4    row-norm A          1      1
# 9  sparsify    bpmf      active         2    row-norm A          1     10
# 10 sparsify    bpmf      active         4    row-norm A          1     10
# 11 sparsify    bpmf      epsilon_greedy 2    row-norm A          1     10
# 12 sparsify    bpmf      epsilon_greedy 4    row-norm A          1     10
# ...

# %%
strategy_colors <- c('random'='black', 'active'='red', 'sequential'='blue', 'epsilon_greedy'='orange')

# %%
plot_aggregate_error(optimality_type='A')
plot_aggregate_error(optimality_type='A', metric='mae')
# Out:
# plot without title
# plot without title

# %%
plot_aggregate_error_inverse(optimality_type='A')
plot_aggregate_error_inverse(optimality_type='A', metric='mae')
# Out:
# plot without title
# plot without title

# %%
plot_method_comparison(optimality_type='A', base_method='active', compare_method='epsilon_greedy')
plot_method_comparison(optimality_type='A', base_method='active', compare_method='epsilon_greedy', metric='mae')
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_path).”
# plot without title
# plot without title

# %%
error_reduction_results <- plot_error_reduction_all(y_var='mae')
# Out:
# Warning message in dir.create(paste0(filepath, "figs/", dataset)):
# “'/Users/cyz/survey/active_survey/figs/cces16' already exists”
# plot without title
# plot without title
# plot without title
# plot without title
